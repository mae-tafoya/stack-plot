# %% [markdown]
# # Stack Plot Example Using Random Numbers

# %%
# import packages
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Create some random data to plot

# %%
x = range (1,21)
y1 = np.random.rand(20)
y2 = np.random.rand(20)

# print values to see what we have
print(x)
print(y1)
print(y2)
# Out:
# range(1, 21)
# [0.20834992 0.38684118 0.76267928 0.18455547 0.55693306 0.93760461
#  0.96775684 0.79750093 0.72653205 0.54013105 0.05028961 0.70039307
#  0.0752255  0.18330607 0.54378939 0.98004837 0.71677769 0.19668974
#  0.40649491 0.50380134]
# [0.73575034 0.75450734 0.80604243 0.18088182 0.14729677 0.77512111
#  0.15676076 0.28426313 0.6861004  0.97299028 0.50201614 0.32107563
#  0.1184365  0.583372   0.62441236 0.69886237 0.94898716 0.2033326
#  0.64325208 0.70684783]

# %%
# setup legend for plot
plt.plot([], [], color = 'r', label = 'y1')
plt.plot([], [], color = 'b', label = 'y2')

# setup the plot
plt.stackplot(x, y1, y2, colors = ['r','b'])
plt.title('Stack Plot Random Numbers')
plt.legend()
plt.show()
